# %% [markdown]
# # 과제1. car seat 매출 분석

# %% [markdown]
# * 카시트에 대해서 지역 매장 별 매출액을 살펴보고자 합니다.
# * 행은 자사 매장이 있는 각 지역별 데이터 입니다.

# %% [markdown]
# ![](https://cdn.images.express.co.uk/img/dynamic/24/590x/child-car-seat-986556.jpg?r=1532946857754)

# %% [markdown]
# ## 0.환경설정
#
# * 필요한 라이브러리 로딩, 데이터셋 가져오기

# %% [markdown]
# ### 1) 라이브러리 로딩

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2) 데이터 불러오기

# %%
path = 'https://raw.githubusercontent.com/JunhoYu/Data-Analysis/main/Carseats.csv'
data = pd.read_csv(path)
data.head()
# Out:
#    Sales  Advertising  Population  Price ShelveLoc  Age
# 0   9.50           11         276    120       Bad   42
# 1  11.22           16         260     83      Good   65
# 2  10.06           10         269     80    Medium   59
# 3   7.40            4         466     97    Medium   55
# 4   4.15            3         340    128       Bad   38

# %% [markdown]
# |	변수명	|	설명	|	구분	|
# |	----	|	----	|	----	|
# |	Sales 	|	 각 지역 판매량(단위 : 1000개)	|	Target	|
# |	CompPrice 	|	 각 지역 경쟁사 가격(단위 : 달러)	|	feature	|
# |	Income 	|	 각 지역 소득수준(단위 : 천달러)	|	feature	|
# |	Advertising 	|	 각 지역, 회사의 광고 예산(단위 : 1000달러)	|	feature	|
# |	Population 	|	 지역 인구수(단위 : 1000명)	|	feature	|
# |	Price 	|	 자사 지역별 판매가격(달러)	|	feature	|
# |	Education 	|	 교육수준(10~18), 범주	|	feature	|
# |	ShelveLoc 	|	 진열상태(Good, Medium, Bad)	|	feature	|
# |	Age 	|	 지역 인구의 평균 연령	|	feature	|
# |	US 	|	 매장이 미국에 있는지 여부(Yes, No)	|	feature	|
# |	Urban 	|	 매장이 도심에 있는지 여부(Yes, No)	|	feature	|

# %% [markdown]
# ## 1.데이터 살펴보기

# %% [markdown]
# * 주어진 데이터로부터 다양한 조회 방법을 통해 비즈니스 사항을 파악해 봅시다.
# * 데이터와 비즈니스를 파악하기 위한 질문을 10개 이상 도출하고, 조회해 봅시다.
